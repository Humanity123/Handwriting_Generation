# %% [markdown]
# # Results

# %%
import sys
sys.path.insert(0, '..')
from utils import plot_stroke

# %% [markdown]
# This is what you should modify:

# %%
from models.dummy import generate_unconditionally, generate_conditionally, recognize_stroke

# %% [markdown]
# Please, don't modify anything below.
#
# ### Unconditional generation:

# %%
stroke = generate_unconditionally()
plot_stroke(stroke)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python2.7/site-packages/tensorflow/python/util/tf_should_use.py:170: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# INFO:tensorflow:Restoring parameters from ../saved_models/uncond/uncond-29
# ../saved_models/uncond/uncond-29 Pre-trained model loaded
# ../models/model_uncond.py:459: RuntimeWarning: covariance is not positive-semidefinite.
#   x1, x2 = np.random.multivariate_normal(mean, cov)
# Strokes Generated

# %% [markdown]
# ### Conditional generation:

# %%
stroke = generate_conditionally(text='welcome to lyrebird')
plot_stroke(stroke)
# Out:
# adas
# WARNING:tensorflow:From /usr/local/lib/python2.7/site-packages/tensorflow/python/util/tf_should_use.py:170: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# INFO:tensorflow:Restoring parameters from ../saved_models/cond/cond-28
# ../saved_models/cond/cond-28 Pre-trained model loaded
# Strokes Generated

# %% [markdown]
# ### Handwriting recognition:

# %%
text = recognize_stroke(stroke)
print text
# Out:
# welcome to lyrebird
